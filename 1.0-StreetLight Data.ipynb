# %%
bRunStreetLightQueries = True

#!/usr/bin/python3

# Sample API client for StreetLight Data API
# This was tested with Python 3 on Ubuntu Linux 16.04.
# Refer to the StreetLight API documentation for more information.

import datetime as dt
import json
import requests
import sys
import time
import pandas as pd

now = dt.datetime.utcnow().isoformat()

# Edit the following two constants to a valid key and user login.
STL_KEY = 'KnsRn7hdgOQjbywguup5hBvCoMcRMNWy'
INSIGHT_LOGIN_EMAIL = 'analytics@wfrc.org'

ZONE_SET_NAME = "WasatchChoiceCenters_WFSmallAnalysisDists"
ANALYSIS_NAME = "WC_Centers_ODAnalysis"

# create data ranges json object

dDateRanges = []

for y in range(2019, 2022): # end value not included in range
    # Create date ranges for each month of year in range
    for m in range(1, 13):
        dtMonthBeg = dt.datetime(y, m, 1)
        dtMonthEnd = dt.date(y + int(m / 12), (m % 12) + 1, 1) - dt.timedelta(days=1)
        dDateRanges.append(
            {
                'date_range_name': dtMonthBeg.strftime("%Y_%m"),
                'data_ranges'    : [{"start_date": dtMonthBeg.strftime("%m/%d/%Y") ,"end_date": dtMonthEnd.strftime("%m/%d/%Y")}]
            }
        )
        #print(dic)    
    # Add best months "BM" ranges for each year from April 1 through October 31
    dtBeg = dt.datetime(y, 4, 1)
    dtEnd = dt.datetime(y,10,31)
    dDateRanges.append(
        {
            'date_range_name': str(y) + "_BM",
            'data_ranges'    : [{"start_date": dtBeg.strftime("%m/%d/%Y") ,"end_date": dtEnd.strftime("%m/%d/%Y")}]
        }
    )
    # Add best year ranges for each year
    dtBeg = dt.datetime(y, 1, 1)
    dtEnd = dt.datetime(y,12,31)
    dDateRanges.append(
        {
            'date_range_name': str(y) + "_YR",
            'data_ranges'    : [{"start_date": dtBeg.strftime("%m/%d/%Y") ,"end_date": dtEnd.strftime("%m/%d/%Y")}]
        }
    )
    
dfDateRanges = pd.DataFrame(dDateRanges)
dfDateRanges.to_csv('rsg_datarequest\\streetlight_smalldist_bicycle_data\\date_ranges.csv',index=False)
#display(dfDateRanges)

# create Modes df
dModes = [
            ['TRU','Truck'],
            ['BIC','Bicycle'],
            ['PED','Pedestrian'],
            ['BUS','Bus'],
            ['RAI','Rail'],
            ['ALL','All_Vehicles']
         ]

dfModes = pd.DataFrame(dModes, columns = ['mode_name','mode_description'])
#display(dfModes)

# create cross recordset for analysis
dfAnalysisSets = pd.DataFrame.merge(dfDateRanges, dfModes, how='cross')
dfAnalysisSets['analysis_set_name'] = ANALYSIS_NAME + '_' + dfAnalysisSets['date_range_name'].astype(str) + '_' + dfAnalysisSets['mode_name'].astype(str) + '_revbins'

# rail and bus analysis periods only include April, May, September, and October of 2019 and 2020
for index, row in dfAnalysisSets.iterrows():
    if (row['mode_description']=='Rail' or row['mode_description']=='Bus'):
        if row['date_range_name'] not in ('2019_04','2019_05','2019_09','2019_10','2020_04','2020_05','2020_09','2020_10'):
            dfAnalysisSets.drop(index, inplace=True)

# add analysis toggle
dfAnalysisSets['RunQuery'] = True
#dfAnalysisSets['RunQuery'] = False
#dfAnalysisSets.loc[dfAnalysisSets['date_range_name'].str[-3:]=='_YR', 'RunQuery'] = True
#dfAnalysisSets.loc[dfAnalysisSets['analysis_set_name']=='WC_Centers_ODAnalysis_2019_01_ALL_revbins2', 'RunQuery'] = True
display(dfAnalysisSets)

def print_response(response):
    print("response code: {}".format(response.status_code))
    print("response body: {}".format(response.content))
# Out:
#     date_range_name                                        data_ranges  \
# 0           2019_01  [{'start_date': '01/01/2019', 'end_date': '01/...
# 1           2019_01  [{'start_date': '01/01/2019', 'end_date': '01/...
# 2           2019_01  [{'start_date': '01/01/2019', 'end_date': '01/...
# 5           2019_01  [{'start_date': '01/01/2019', 'end_date': '01/...
# 6           2019_02  [{'start_date': '02/01/2019', 'end_date': '02/...
# ..              ...                                                ...
# 245         2021_BM  [{'start_date': '04/01/2021', 'end_date': '10/...
# 246         2021_YR  [{'start_date': '01/01/2021', 'end_date': '12/...
# 247         2021_YR  [{'start_date': '01/01/2021', 'end_date': '12/...
# 248         2021_YR  [{'start_date': '01/01/2021', 'end_date': '12/...
# 251         2021_YR  [{'start_date': '01/01/2021', 'end_date': '12/...
#
#     mode_name mode_description                          analysis_set_name  \
# 0         TRU            Truck  WC_Centers_ODAnalysis_2019_01_TRU_revbins
# 1         BIC          Bicycle  WC_Centers_ODAnalysis_2019_01_BIC_revbins
# 2         PED       Pedestrian  WC_Centers_ODAnalysis_2019_01_PED_revbins
# 5         ALL     All_Vehicles  WC_Centers_ODAnalysis_2019_01_ALL_revbins
# 6         TRU            Truck  WC_Centers_ODAnalysis_2019_02_TRU_revbins
# ..        ...              ...                                        ...
# 245       ALL     All_Vehicles  WC_Centers_ODAnalysis_2021_BM_ALL_revbins
# 246       TRU            Truck  WC_Centers_ODAnalysis_2021_YR_TRU_revbins
# 247       BIC          Bicycle  WC_Centers_ODAnalysis_2021_YR_BIC_revbins
# 248       PED       Pedestrian  WC_Centers_ODAnalysis_2021_YR_PED_revbins
# 251       ALL     All_Vehicles  WC_Centers_ODAnalysis_2021_YR_ALL_revbins
#
#      RunQuery
# 0        True
# 1        True
# 2        True
# 5        True
# 6        True
# ..        ...
# 245      True
# 246      True
# 247      True
# 248      True
# 251      True
#
# [184 rows x 6 columns]

# %%
#----------------------------------------------------------------------------------------
# Create a Zone Set.
#----------------------------------------------------------------------------------------

#ZONE_SET_REQUEST = {
#    "insight_login_email": INSIGHT_LOGIN_EMAIL,
#    "zone_set_name": ZONE_SET_NAME,
#    "zones": {
#        "type": "FeatureCollection",
#        "features": [
#            { "type": "Feature", "properties": { "id": 1, "name": "Mission", "is_pass": 0, "direction": None }, "geometry": { "type": "MultiPolygon", "coordinates": [ [ [ [ -122.426698258661972, 37.769562689936315 ], [ -122.423394859041892, 37.772083876030344 ], [ -122.42225575572462, 37.770418101996292 ], [ -122.411206453547067, 37.769427623969634 ], [ -122.406991771273155, 37.769067446852375 ], [ -122.404656609472752, 37.767716767038294 ], [ -122.405169205965521, 37.762628984940662 ], [ -122.406593085112107, 37.760557752167074 ], [ -122.405795712790038, 37.758441432691242 ], [ -122.403232730326167, 37.75722564731312 ], [ -122.402549268335804, 37.751821915004783 ], [ -122.403346640657901, 37.749390106706535 ], [ -122.407561322931784, 37.748399347080543 ], [ -122.424875693354338, 37.74781389197571 ], [ -122.426698258661972, 37.769562689936315 ] ] ] ] } },
#            { "type": "Feature", "properties": { "id": 2, "name": "Financial District", "is_pass": 1, "direction": None }, "geometry": { "type": "MultiPolygon", "coordinates": [ [ [ [ -122.405425504211919, 37.798033588378779 ], [ -122.398476973976571, 37.798933675051543 ], [ -122.396654408668923, 37.799698740100226 ], [ -122.397024617247041, 37.79929370664977 ], [ -122.396768319000643, 37.798911173018389 ], [ -122.395828558763895, 37.797898574431919 ], [ -122.393607307295227, 37.799113691070012 ], [ -122.392610591892605, 37.797876072083447 ], [ -122.394233814119715, 37.79690846455324 ], [ -122.393037755636598, 37.795670808599994 ], [ -122.3913575782436, 37.796278387822021 ], [ -122.390987369665496, 37.795693311702443 ], [ -122.392439726395011, 37.794500642185817 ], [ -122.389278714689581, 37.791462623416393 ], [ -122.401182344355107, 37.781965196242638 ], [ -122.405824190372982, 37.785701296639232 ], [ -122.406222876534017, 37.785723802695827 ], [ -122.407134159187834, 37.790337399578668 ], [ -122.404058580231194, 37.790764986655553 ], [ -122.405425504211919, 37.798033588378779 ] ] ] ] } }
#        ]
#    }
#}
#
#resp = requests.post(
#    'https://insight.streetlightdata.com/api/v2/zone_sets',
#    headers = {'content-type': 'application/json', 'x-stl-key': STL_KEY},
#    data = json.dumps(ZONE_SET_REQUEST))
#
#print_response(resp)
#
#if (resp.status_code == 201):
#    print("Created Zone Set successfully.")
#else:
#    print("Error creating Zone Set.")
#    sys.exit(1)
#
#

# %%
#----------------------------------------------------------------------------------------
# Create an O-D Analysis.
#----------------------------------------------------------------------------------------

if bRunStreetLightQueries:
    
    for index, row in dfAnalysisSets.iterrows():
        
        if row['RunQuery']==True:

            print(row['analysis_set_name'])

            CREATE_ANALYSIS_REQUEST = {
                "insight_login_email": INSIGHT_LOGIN_EMAIL,
                "analysis_name": row['analysis_set_name'],
                "analysis_type": "OD_Analysis",
                "travel_mode_type": row['mode_description'],
                "description": "",
                "oz_sets": [{"name":ZONE_SET_NAME}],
                "dz_sets": [{"name":ZONE_SET_NAME}],
                "date_ranges": row['data_ranges'],
                "day_types": "All Days|17, Weekday_TuWeTh|24, Weekend_SaSu|67",
                "day_parts": "All Day|0023, Early AM (12am-6am)|0005, Peak AM (6am-9am)|0608, Mid-Day (9am-3pm)|0914, Peak PM (3pm-6pm)|1517, Late PM (6pm-12am)|1823",
                "trip_attributes": True
            }

            # traveler attributes only exist for non-Truck modes
            if (row['mode_description']!='Truck'):
                CREATE_ANALYSIS_REQUEST['traveler_attributes'] = True
                #CREATE_ANALYSIS_REQUEST['truck_weight'] = 'Medium,Heavy'

            #print(CREATE_ANALYSIS_REQUEST)
            resp = requests.post(
                'https://insight.streetlightdata.com/api/v2/analyses',
                headers = {'content-type': 'application/json', 'x-stl-key': STL_KEY},
                data = json.dumps(CREATE_ANALYSIS_REQUEST))

            print_response(resp)

            if (resp.status_code == 201):
                print("Created Analysis successfully.")
                time.sleep(10) # wait ten seconds since URL has max limit of 3 calls per 15 seconds
            else:
                print("Error creating Analysis.")
                sys.exit(1)
# Out:
# WC_Centers_ODAnalysis_2019_01_TRU_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_01_TRU_revbins","status":"success","uuid":"0dec608d-7218-413c-8713-7af2826ff0d8"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_01_BIC_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_01_BIC_revbins","status":"success","uuid":"57542b5c-6137-4236-aeb6-fba3d7d1936b"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_01_PED_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_01_PED_revbins","status":"success","uuid":"f35536cc-3095-4e4b-b762-707322cc7320"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_01_ALL_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_01_ALL_revbins","status":"success","uuid":"56474ce7-38d3-46fb-93cc-292c4dd0610c"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_02_TRU_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_02_TRU_revbins","status":"success","uuid":"fd64239a-3bae-4d68-88ce-213e5bcf593d"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_02_BIC_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_02_BIC_revbins","status":"success","uuid":"cf3dd2d4-ccd3-4760-95c6-a4fc55eac17f"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_02_PED_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_02_PED_revbins","status":"success","uuid":"a2994b4a-9d70-46e3-a2e6-509a9d913ac5"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_02_ALL_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_02_ALL_revbins","status":"success","uuid":"f8174592-e367-4060-8785-fcb682d02c76"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_03_TRU_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_03_TRU_revbins","status":"success","uuid":"26c84844-2162-4dbd-a554-f4e71f0e563d"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_03_BIC_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_03_BIC_revbins","status":"success","uuid":"18bdc99d-a2ea-4ad2-9a28-f746b31c0f6f"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_03_PED_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_03_PED_revbins","status":"success","uuid":"0d05999a-9171-4d82-8ca5-3dce98378655"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_03_ALL_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_03_ALL_revbins","status":"success","uuid":"1714cd37-1b41-4fd8-9e00-ad902daa202a"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_04_TRU_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_04_TRU_revbins","status":"success","uuid":"87ccd9bc-e30d-4454-92d8-65a338e6c9ca"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_04_BIC_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_04_BIC_revbins","status":"success","uuid":"aceb20d7-f84e-44ec-8007-54a6015b0680"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_04_PED_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_04_PED_revbins","status":"success","uuid":"08c519ab-4f0c-4c4a-8e0b-59ccb0749ee6"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_04_BUS_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_04_BUS_revbins","status":"success","uuid":"f19ecc02-71ec-4f2d-8884-dc21190401ab"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_04_RAI_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_04_RAI_revbins","status":"success","uuid":"ee4414d4-2a1a-41e4-9491-ed2a81196014"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_04_ALL_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_04_ALL_revbins","status":"success","uuid":"7b78a188-96f6-41cf-9cdc-3766887cd5e6"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_05_TRU_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_05_TRU_revbins","status":"success","uuid":"99047e6b-6d61-4f8d-bc73-f2b84185fc67"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_05_BIC_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_05_BIC_revbins","status":"success","uuid":"799d05f8-30fa-44a1-bec0-3ce5b801144f"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_05_PED_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_05_PED_revbins","status":"success","uuid":"2f15a490-8572-439c-886a-0cdd63990b87"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_05_BUS_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_05_BUS_revbins","status":"success","uuid":"df3051a6-abd2-4eef-b701-496285ff8815"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_05_RAI_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_05_RAI_revbins","status":"success","uuid":"dca742a3-0737-497c-97b0-5edd9b9d7a98"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_05_ALL_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_05_ALL_revbins","status":"success","uuid":"87a30971-2e72-4f5b-97d0-8661f7bd15b5"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_06_TRU_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_06_TRU_revbins","status":"success","uuid":"97efe50e-a135-462f-9b2e-d4145160bef7"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_06_BIC_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_06_BIC_revbins","status":"success","uuid":"e7d89eab-399f-4d2f-b032-5d98f4163338"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_06_PED_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_06_PED_revbins","status":"success","uuid":"54e9feb9-e5d2-4ad6-bcfb-2d2c4129b3d1"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_06_ALL_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_06_ALL_revbins","status":"success","uuid":"bcaec198-18a2-449a-8e73-31dbde11eea4"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_07_TRU_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_07_TRU_revbins","status":"success","uuid":"2faa50af-3a8d-4f9b-8703-48b3166e2e11"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_07_BIC_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_07_BIC_revbins","status":"success","uuid":"4b617aa0-82a3-42ea-9b91-6e50b454e4fd"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_07_PED_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_07_PED_revbins","status":"success","uuid":"e81ea2a9-eaa4-4976-b120-d2cdd1d84dd5"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_07_ALL_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_07_ALL_revbins","status":"success","uuid":"5980bb81-e27f-4ba9-8700-543ce2f9035b"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_08_TRU_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_08_TRU_revbins","status":"success","uuid":"9f50ec87-3753-4b3b-84fd-94d75113c132"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_08_BIC_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_08_BIC_revbins","status":"success","uuid":"e7932e8c-77c9-4b62-89ea-80f3a8f3c7a6"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_08_PED_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_08_PED_revbins","status":"success","uuid":"3140b19b-5933-4669-ba28-29e6b512fd4e"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_08_ALL_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_08_ALL_revbins","status":"success","uuid":"1846fdae-162f-453a-a686-85fddd360ab4"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_09_TRU_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_09_TRU_revbins","status":"success","uuid":"b8022eb7-70b3-48c2-b9ce-0a7a6a749dcc"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_09_BIC_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_09_BIC_revbins","status":"success","uuid":"6962920d-66e8-4938-84fc-feddaa517fc5"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_09_PED_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_09_PED_revbins","status":"success","uuid":"8648f5c5-0346-4bae-8333-36c94a5ba775"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_09_BUS_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_09_BUS_revbins","status":"success","uuid":"d4ba7140-c8ad-4b8f-aa6b-56306d1fa7ab"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_09_RAI_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_09_RAI_revbins","status":"success","uuid":"2a0e32f6-8123-4ac9-b30a-043049c8d9ab"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_09_ALL_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_09_ALL_revbins","status":"success","uuid":"06e78b9d-059a-4699-9379-34cc589120d0"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_10_TRU_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_10_TRU_revbins","status":"success","uuid":"c5258aa8-d118-45f1-b6e2-2e666a9982e4"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_10_BIC_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_10_BIC_revbins","status":"success","uuid":"8d6641c3-c51a-427b-a0d3-494e854f6351"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_10_PED_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_10_PED_revbins","status":"success","uuid":"efcf2640-7ea4-4ace-9e70-781c2eb77656"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_10_BUS_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_10_BUS_revbins","status":"success","uuid":"b979b6a4-60da-427c-b6e0-936a82c44c42"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_10_RAI_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_10_RAI_revbins","status":"success","uuid":"f3781f77-a892-4a7b-88cc-28cb647674cc"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_10_ALL_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_10_ALL_revbins","status":"success","uuid":"3fdf9516-52f8-4f2a-931e-f955909955ce"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_11_TRU_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_11_TRU_revbins","status":"success","uuid":"4fd353b6-186a-41f3-a37a-501485b1cc6b"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_11_BIC_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_11_BIC_revbins","status":"success","uuid":"96d1b0e7-f8a3-4f0f-8eb2-0be3f2392f57"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_11_PED_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_11_PED_revbins","status":"success","uuid":"7ad7607d-afb2-4b11-a1c6-62e22c2622e5"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_11_ALL_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_11_ALL_revbins","status":"success","uuid":"07b0cd63-3a79-4ec6-a54b-db2052a26b29"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_12_TRU_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_12_TRU_revbins","status":"success","uuid":"f7e86150-9522-49e8-a607-a66bf05220c4"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_12_BIC_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_12_BIC_revbins","status":"success","uuid":"47a194e4-8c8d-46bf-a2c0-ca1d278bdd7b"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_12_PED_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_12_PED_revbins","status":"success","uuid":"8d074f52-8f9a-4db7-9d96-bb2bb5b63381"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_12_ALL_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_12_ALL_revbins","status":"success","uuid":"bb0a878a-0c60-425b-a1c2-86e98c9addcc"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_BM_TRU_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_BM_TRU_revbins","status":"success","uuid":"be41d143-bb24-4395-ac5b-5a15e8b020f5"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_BM_BIC_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_BM_BIC_revbins","status":"success","uuid":"07ed235c-74bc-45d2-b943-d1b2b7b6b573"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_BM_PED_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_BM_PED_revbins","status":"success","uuid":"98ce49e8-efac-4fc8-b4b8-1c7b70fe83fe"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_BM_ALL_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_BM_ALL_revbins","status":"success","uuid":"b42fa561-5ee5-455f-b527-c0fd4d1f92b9"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_YR_TRU_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_YR_TRU_revbins","status":"success","uuid":"f30657e8-8f45-402e-af01-d664f58eaade"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_YR_BIC_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_YR_BIC_revbins","status":"success","uuid":"921d0405-6ec1-4bda-b4ec-173dce342636"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_YR_PED_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_YR_PED_revbins","status":"success","uuid":"42fefa00-bb67-4f04-aba8-5372fecc6c04"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2019_YR_ALL_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2019_YR_ALL_revbins","status":"success","uuid":"15f3422d-074e-40f2-8e98-e6dbe35d9deb"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_01_TRU_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_01_TRU_revbins","status":"success","uuid":"97c7abd3-ccb7-40a6-8737-4c9c925969bc"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_01_BIC_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_01_BIC_revbins","status":"success","uuid":"321a5e44-a77f-42b3-b49a-c7a92dde8414"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_01_PED_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_01_PED_revbins","status":"success","uuid":"c23b75ef-6145-44af-b62a-eeb87a0a1f10"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_01_ALL_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_01_ALL_revbins","status":"success","uuid":"cec92008-419b-4cce-883c-19dd02c8fefb"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_02_TRU_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_02_TRU_revbins","status":"success","uuid":"56f7d783-71cc-4144-9989-f2001994465e"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_02_BIC_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_02_BIC_revbins","status":"success","uuid":"d4df18d4-2718-444c-b348-012788761248"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_02_PED_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_02_PED_revbins","status":"success","uuid":"b54dda2a-33d7-41f9-950e-cef292cfc697"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_02_ALL_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_02_ALL_revbins","status":"success","uuid":"a1948e40-53ff-4272-b51e-cc31dc1bcc46"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_03_TRU_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_03_TRU_revbins","status":"success","uuid":"9e4c87fe-1f43-4120-b667-fb2daebea73c"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_03_BIC_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_03_BIC_revbins","status":"success","uuid":"51009717-9cc7-43ff-964a-08e16095d272"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_03_PED_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_03_PED_revbins","status":"success","uuid":"c9572908-4a16-49c0-b89c-17a57ac1c870"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_03_ALL_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_03_ALL_revbins","status":"success","uuid":"d9303947-489d-4594-9ef1-c3d62ad82f1c"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_04_TRU_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_04_TRU_revbins","status":"success","uuid":"17e8eee1-dc8c-4737-944a-f6566a869ed2"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_04_BIC_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_04_BIC_revbins","status":"success","uuid":"8e04b2ca-b6c3-480d-a8fe-3dcdbecb17e1"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_04_PED_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_04_PED_revbins","status":"success","uuid":"555cc6ab-2477-473c-aac3-f11a57b1efde"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_04_BUS_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_04_BUS_revbins","status":"success","uuid":"0e565fce-7e38-4019-9b3d-8de7fb85b125"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_04_RAI_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_04_RAI_revbins","status":"success","uuid":"c7d70d8d-1170-446c-aa8d-1597497dc81f"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_04_ALL_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_04_ALL_revbins","status":"success","uuid":"892effdf-8d2d-4978-9188-b3d4add61638"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_05_TRU_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_05_TRU_revbins","status":"success","uuid":"bd482d16-029b-47b2-928d-e411feef3605"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_05_BIC_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_05_BIC_revbins","status":"success","uuid":"bead15d5-f66e-4187-bc7f-37cfe494a0e5"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_05_PED_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_05_PED_revbins","status":"success","uuid":"2ad8d728-a3c2-45aa-a806-e45ac06bb691"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_05_BUS_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_05_BUS_revbins","status":"success","uuid":"1d324507-5415-4340-a42e-094e54a9692d"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_05_RAI_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_05_RAI_revbins","status":"success","uuid":"186e9273-5db6-439b-80d6-df57e82f4e78"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_05_ALL_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_05_ALL_revbins","status":"success","uuid":"d49fc271-bcfd-4cb1-b715-437653091e92"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_06_TRU_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_06_TRU_revbins","status":"success","uuid":"5f788fcd-3089-46d4-aa18-bf72e9178e0c"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_06_BIC_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_06_BIC_revbins","status":"success","uuid":"c780cee5-140e-4532-818b-17c21a4428f3"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_06_PED_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_06_PED_revbins","status":"success","uuid":"47a2dccd-dd21-4f70-82c4-cfcc981d709b"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_06_ALL_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_06_ALL_revbins","status":"success","uuid":"9c27d7b2-318d-4c3e-a63e-5a00aad4fa46"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_07_TRU_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_07_TRU_revbins","status":"success","uuid":"839187f7-6012-4257-a7c1-455d48be84d2"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_07_BIC_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_07_BIC_revbins","status":"success","uuid":"186926c1-ef56-4d47-965f-2af9ffd8406c"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_07_PED_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_07_PED_revbins","status":"success","uuid":"fea465b8-9648-47a1-bbbb-33bc90073620"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_07_ALL_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_07_ALL_revbins","status":"success","uuid":"f96cbbe7-95f0-43cd-a2d5-b077a0c00b56"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_08_TRU_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_08_TRU_revbins","status":"success","uuid":"9b38f31b-a859-4587-b1a4-b2e8d7255a72"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_08_BIC_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_08_BIC_revbins","status":"success","uuid":"7fe9be57-27c9-40a6-8b0b-47f85382f9ee"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_08_PED_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_08_PED_revbins","status":"success","uuid":"ddd8edb3-178e-49fa-96c3-e8a566716377"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_08_ALL_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_08_ALL_revbins","status":"success","uuid":"41bd8101-e221-4474-9eb8-18c709872fdf"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_09_TRU_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_09_TRU_revbins","status":"success","uuid":"f421212a-dcc4-41e8-8ce2-2e33a71c207d"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_09_BIC_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_09_BIC_revbins","status":"success","uuid":"3a8c1957-1b60-4728-bc75-55a50177a819"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_09_PED_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_09_PED_revbins","status":"success","uuid":"96c713ce-8ac7-493a-8f4c-7e2426ccf061"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_09_BUS_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_09_BUS_revbins","status":"success","uuid":"0992dad3-2faf-4e61-bd16-083759f3eda3"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_09_RAI_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_09_RAI_revbins","status":"success","uuid":"2d717570-7723-49c8-a049-0c0933f5a755"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_09_ALL_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_09_ALL_revbins","status":"success","uuid":"9d9f6110-0132-41f2-8e0d-1952bc237624"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_10_TRU_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_10_TRU_revbins","status":"success","uuid":"972d84c7-c754-4fc1-9b61-ca0e0a653b73"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_10_BIC_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_10_BIC_revbins","status":"success","uuid":"8e350984-28e7-42c5-becb-8ddc943564ba"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_10_PED_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_10_PED_revbins","status":"success","uuid":"dd995dc9-fc36-4d46-b787-42c8fd8cebd3"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_10_BUS_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_10_BUS_revbins","status":"success","uuid":"2550c59a-ac60-4bf5-adfe-bb87ee0c0389"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_10_RAI_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_10_RAI_revbins","status":"success","uuid":"7d1422de-fd3a-4aa7-a4e4-53fc1ee40222"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_10_ALL_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_10_ALL_revbins","status":"success","uuid":"f3c5d32c-6eb2-421b-a43d-f1ef870f53f8"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_11_TRU_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_11_TRU_revbins","status":"success","uuid":"9abe7490-c4be-4bf8-b3f9-023605143d10"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_11_BIC_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_11_BIC_revbins","status":"success","uuid":"402f5ff7-8302-4e89-a000-e77553b8cf6d"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_11_PED_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_11_PED_revbins","status":"success","uuid":"1888b6b3-7799-4dc2-b40e-ee697e8dab3f"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_11_ALL_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_11_ALL_revbins","status":"success","uuid":"8889b4ee-20f9-42f5-9aad-cd4da45e088d"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_12_TRU_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_12_TRU_revbins","status":"success","uuid":"2657aa3f-61e0-47ff-89fe-6ef3886c5c96"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_12_BIC_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_12_BIC_revbins","status":"success","uuid":"ec4815ea-fe26-4b35-9ef5-077ff5313805"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_12_PED_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_12_PED_revbins","status":"success","uuid":"c8a192b7-7c82-473d-a942-8b5f2375816d"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_12_ALL_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_12_ALL_revbins","status":"success","uuid":"5fb776b4-bcaf-48bb-8ae7-0291ca8689dc"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_BM_TRU_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_BM_TRU_revbins","status":"success","uuid":"12481da1-e43e-48f1-a3a6-095b1fbdf5ee"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_BM_BIC_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_BM_BIC_revbins","status":"success","uuid":"df141422-6659-4e29-8a5c-8fecb4078e65"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_BM_PED_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_BM_PED_revbins","status":"success","uuid":"bbea5f19-6b8a-4725-a0be-e45994472253"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_BM_ALL_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_BM_ALL_revbins","status":"success","uuid":"eee0db6d-abeb-4194-9e0a-1e029a31c56a"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_YR_TRU_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_YR_TRU_revbins","status":"success","uuid":"6d3b98d3-2936-41a1-978d-b08f4688dc4c"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_YR_BIC_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_YR_BIC_revbins","status":"success","uuid":"152a8be6-96e6-4369-91bc-8d5218f8abce"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_YR_PED_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_YR_PED_revbins","status":"success","uuid":"fdfcf550-1122-422b-9583-32ecafbfee7e"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2020_YR_ALL_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2020_YR_ALL_revbins","status":"success","uuid":"c0de3ed2-64e6-4e17-9397-5384d8f18372"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_01_TRU_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_01_TRU_revbins","status":"success","uuid":"be155dde-5ad6-4b32-9656-f7e9b2e84569"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_01_BIC_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_01_BIC_revbins","status":"success","uuid":"915725c1-ac93-4f5b-8e1b-88991dacc610"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_01_PED_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_01_PED_revbins","status":"success","uuid":"e2e38771-6eef-4e9c-9e29-28e2a5f47517"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_01_ALL_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_01_ALL_revbins","status":"success","uuid":"d6e6a2fb-7d83-410a-931c-cd278a0ae8f5"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_02_TRU_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_02_TRU_revbins","status":"success","uuid":"5ab84e64-a2f2-406b-b9f9-99347b7ed198"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_02_BIC_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_02_BIC_revbins","status":"success","uuid":"ad1fb3ce-71b1-4c26-9cbe-24107c7d42bc"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_02_PED_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_02_PED_revbins","status":"success","uuid":"f88e4482-1ff8-40d3-b73d-3f26817ba7d0"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_02_ALL_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_02_ALL_revbins","status":"success","uuid":"69717d96-eec6-418c-872b-fac8abc1ed4b"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_03_TRU_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_03_TRU_revbins","status":"success","uuid":"a3187c54-8094-4aad-9475-416b46f0f5fe"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_03_BIC_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_03_BIC_revbins","status":"success","uuid":"48fa4cb7-431a-4a40-8ef0-dafd6445130d"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_03_PED_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_03_PED_revbins","status":"success","uuid":"516cb2b7-0159-4894-8eed-c224dca9e317"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_03_ALL_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_03_ALL_revbins","status":"success","uuid":"0878ef6d-2211-42cd-9f35-f2974f58692f"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_04_TRU_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_04_TRU_revbins","status":"success","uuid":"2aa67188-8036-4586-994b-472bcb8ab439"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_04_BIC_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_04_BIC_revbins","status":"success","uuid":"5a413a02-39a0-47eb-a20b-d599046b5449"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_04_PED_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_04_PED_revbins","status":"success","uuid":"dfa7def4-0d57-46f7-998b-90e36a96bcde"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_04_ALL_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_04_ALL_revbins","status":"success","uuid":"7c3464b4-1253-4f7f-b572-eea5075d5da8"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_05_TRU_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_05_TRU_revbins","status":"success","uuid":"2d7ba6bb-096a-474c-85dd-d8d916704088"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_05_BIC_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_05_BIC_revbins","status":"success","uuid":"bbbbc474-4b04-4648-8f97-1c6e0d35fc3b"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_05_PED_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_05_PED_revbins","status":"success","uuid":"224876c3-1da7-4ec6-838b-77878045c5d2"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_05_ALL_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_05_ALL_revbins","status":"success","uuid":"b90079ab-a382-4eef-9ef9-baab584b264a"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_06_TRU_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_06_TRU_revbins","status":"success","uuid":"4228f0fb-054f-415b-b7be-d0eab52de298"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_06_BIC_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_06_BIC_revbins","status":"success","uuid":"d21f500a-5110-4996-914a-eba15661c9fb"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_06_PED_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_06_PED_revbins","status":"success","uuid":"e5e79d0d-5791-405b-afe7-330c7e6fe779"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_06_ALL_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_06_ALL_revbins","status":"success","uuid":"90e658af-f030-4b93-a542-ba000aded80a"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_07_TRU_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_07_TRU_revbins","status":"success","uuid":"ae024008-aedd-4705-b996-d978b0fb049d"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_07_BIC_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_07_BIC_revbins","status":"success","uuid":"2bc9d7f1-767a-4c26-bc96-bbef4afe63f9"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_07_PED_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_07_PED_revbins","status":"success","uuid":"e84ea730-2de1-4e69-8f81-d4e0fe080064"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_07_ALL_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_07_ALL_revbins","status":"success","uuid":"b1a80e29-1a52-4bc2-8da1-b94d9b6d41cd"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_08_TRU_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_08_TRU_revbins","status":"success","uuid":"162b8c9d-a0a8-4be7-80c9-faef1176f82b"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_08_BIC_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_08_BIC_revbins","status":"success","uuid":"50ecc7b6-41b5-4ba7-9e10-17f55607f9d4"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_08_PED_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_08_PED_revbins","status":"success","uuid":"e2f64ea8-561a-4a77-b17d-bde718852166"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_08_ALL_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_08_ALL_revbins","status":"success","uuid":"902999b9-902d-457c-8fcb-f47503453840"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_09_TRU_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_09_TRU_revbins","status":"success","uuid":"deb5d74e-e98b-4f3c-a230-587faa49b3cc"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_09_BIC_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_09_BIC_revbins","status":"success","uuid":"377aea48-34e8-4831-90a3-0080d70e2bdf"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_09_PED_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_09_PED_revbins","status":"success","uuid":"09c8dee7-8627-492b-8511-19a3fe4bb11a"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_09_ALL_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_09_ALL_revbins","status":"success","uuid":"8347bc08-d8ad-4d79-8436-a3b229bf7d83"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_10_TRU_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_10_TRU_revbins","status":"success","uuid":"73811df0-b45b-4b4d-85bc-8d99929d5321"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_10_BIC_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_10_BIC_revbins","status":"success","uuid":"2704662f-bb83-4a49-8490-c0512ea55259"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_10_PED_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_10_PED_revbins","status":"success","uuid":"014534e8-5990-48ce-ac8f-705bd756bac9"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_10_ALL_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_10_ALL_revbins","status":"success","uuid":"ae8aa7cb-8c43-4387-af31-323df8722df7"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_11_TRU_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_11_TRU_revbins","status":"success","uuid":"2f5089ab-7367-4d8c-9e28-062570c8baa3"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_11_BIC_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_11_BIC_revbins","status":"success","uuid":"3fe96a87-3804-47c2-9e2e-ac9fd3a22ccb"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_11_PED_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_11_PED_revbins","status":"success","uuid":"d624903e-4c33-4b33-88a9-97f9d89165c5"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_11_ALL_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_11_ALL_revbins","status":"success","uuid":"7db7653f-2e85-499d-ad6f-ec74d6e7e573"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_12_TRU_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_12_TRU_revbins","status":"success","uuid":"929ebf96-d65c-4aab-adf1-4ee2e4c0119c"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_12_BIC_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_12_BIC_revbins","status":"success","uuid":"144e50ae-abfb-4ede-befb-0c4def82d5cb"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_12_PED_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_12_PED_revbins","status":"success","uuid":"f87de41e-7af6-4c28-9e67-6e0ea46fe896"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_12_ALL_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_12_ALL_revbins","status":"success","uuid":"f36109f9-035a-4b86-ae98-7294c6407548"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_BM_TRU_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_BM_TRU_revbins","status":"success","uuid":"ebf05927-af92-4b50-9098-0fa340caf3ad"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_BM_BIC_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_BM_BIC_revbins","status":"success","uuid":"3805358c-ad0b-4e07-93cd-0ce13984a34f"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_BM_PED_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_BM_PED_revbins","status":"success","uuid":"dcaee366-09f6-444a-9248-4158873fe4b4"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_BM_ALL_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_BM_ALL_revbins","status":"success","uuid":"8e1d96a0-c250-4062-a564-8d49c47f6be0"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_YR_TRU_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_YR_TRU_revbins","status":"success","uuid":"33694d81-f07e-4d10-b556-8f7a644444b6"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_YR_BIC_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_YR_BIC_revbins","status":"success","uuid":"c2c08e3e-64df-40ec-ae6f-1d85b7a1b7c1"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_YR_PED_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_YR_PED_revbins","status":"success","uuid":"e1abf9c8-1356-4928-98b8-135b1e3feae3"}\n'
# Created Analysis successfully.
# WC_Centers_ODAnalysis_2021_YR_ALL_revbins
# response code: 201
# response body: b'{"name":"WC_Centers_ODAnalysis_2021_YR_ALL_revbins","status":"success","uuid":"cf505846-9410-4fa7-8821-daf629e1ac50"}\n'
# Created Analysis successfully.

# %%
#----------------------------------------------------------------------------------------
# Check the processing status of the Analysis.
#
# Note: depending on Analysis size, Analysis processing can take minutes to hours
# (for very large Analyses). A production integration should not block UI input
# from the end user while Analyses are processing, and it should resume
# gracefully when the client application is shut down and restarted while
# Analyses process.
#----------------------------------------------------------------------------------------


#pick a month that has all modes
dfOneOfEachMode = dfAnalysisSets[dfAnalysisSets['analysis_set_name'].str.contains("WC_Centers_ODAnalysis_2019_04")]


for index, row in dfOneOfEachMode.iterrows():

    print(row['analysis_set_name'])

    CHECK_STATUS_REQUEST = {
        "analyses":[{"name": row['analysis_set_name']}]
    }

    resp = requests.post(
        'https://insight.streetlightdata.com/api/v2/analyses/status',
        headers = {'content-type': 'application/json', 'x-stl-key': STL_KEY},
        data = json.dumps(CHECK_STATUS_REQUEST))

    print_response(resp)

    if (resp.status_code != 200):
        print("Error checking Analysis Status.")
        sys.exit(1)

    json_result = json.loads(resp.text)
    analysis_status = json_result["analyses"][0]["status"]

    if (analysis_status == "Available"):
        print("Analysis is Available!")
        time.sleep(10)
        break
    elif (analysis_status == "Processing"):
        print("Analysis is processing. Trying again after 1 minute...")
        time.sleep(10)
    else:
        print(analysis_status)
        time.sleep(10)
        #print("Error running Analysis.")
        #sys.exit(1)
#    
#    # only go through first time to get available downloades
#    break
# Out:
# WC_Centers_ODAnalysis_2019_04_TRU
# response code: 200
# response body: b'{"analyses":[{"metrics":["od_comm","zone_od_comm","od_trip_comm","zone_trip_comm"],"name":"WC_Centers_ODAnalysis_2019_04_TRU","status":"Data Available","uuid":"817e20b9-ea3d-4204-ace0-2f468d04e990"}],"status":"success"}\n'
# Data Available
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-d7ac1c547fd6> in <module>
#      45     else:
#      46         print(analysis_status)
# ---> 47         time.sleep(10)
#      48         #print("Error running Analysis.")
#      49         #sys.exit(1)
#
# KeyboardInterrupt:

# %%
_keepfields         = ['Origin Zone ID','Destination Zone ID','Day Type','Day Part','Average Daily O-D Traffic (StL Index)','Avg Travel Time (sec)']
_keepfields_newname = ['OID'           ,'DID'                ,'day_type','day_part','odvolume'                             ,'odtime'               ]

dMetricInputDic = [
    ['TRU','od_comm'],
    ['BUS','od_bus' ],
    ['BIC','od_bike'],
    ['PED','od_ped' ],
    ['RAI','od_rail'],
    ['ALL','od_all' ]
]

dfMetricInputDic = pd.DataFrame(dMetricInputDic, columns = ['mode_name','metric_name'])
display(dfMetricInputDic)

#----------------------------------------------------------------------------------------
# Get the O-D results.
#----------------------------------------------------------------------------------------

#"analyses":[{"metrics":["od_comm","zone_od_comm","od_trip_comm","zone_trip_comm"]

dfImport = pd.DataFrame()

for index, row in dfAnalysisSets.iterrows():

    print("Importing " + row['analysis_set_name'] + "...")

    _metric_name = dfMetricInputDic.loc[(dfMetricInputDic['mode_name']==row['mode_name']), 'metric_name'].values[0]
    
    resp = requests.get(
        'https://insight.streetlightdata.com/api/v2/analyses/download/name/{}'.format(row['analysis_set_name']) + '/' + _metric_name,
        headers = {'x-stl-key': STL_KEY})

    # resp.text contains results in CSV format.
    #print_response(resp)

    if (resp.status_code == 200):
        # Write results to a CSV file.        
        with open("temp.csv", "w") as csv_file:
            csv_file.write(resp.text)
        
        # read csv into temporary dataframe
        dfTemp = pd.read_csv("temp.csv",usecols=_keepfields)

        # rename columns to make shorter
        dfTemp.columns = _keepfields_newname

        # add columns with data from analysis set fields
        dfTemp['mode'      ] = row['mode_name'      ]
        dfTemp['date_range'] = row['date_range_name']

        # append temporary dataframe to Import dataframe
        dfImport = pd.concat([dfImport, dfTemp])

        # pause for 2 seconds due to API restrictions
        time.sleep(2)

        print("Done.")
    else:
        print("Error fetching O-D results.")
        sys.exit(1)
# Out:
#   mode_name metric_name
# 0       TRU     od_comm
# 1       BUS      od_bus
# 2       BIC     od_bike
# 3       PED      od_ped
# 4       RAI     od_rail
# 5       ALL      od_all
# Importing WC_Centers_ODAnalysis_2019_01_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2019_01_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2019_01_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2019_01_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2019_02_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2019_02_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2019_02_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2019_02_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2019_03_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2019_03_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2019_03_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2019_03_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2019_04_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2019_04_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2019_04_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2019_04_BUS...
# Done.
# Importing WC_Centers_ODAnalysis_2019_04_RAI...
# Done.
# Importing WC_Centers_ODAnalysis_2019_04_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2019_05_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2019_05_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2019_05_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2019_05_BUS...
# Done.
# Importing WC_Centers_ODAnalysis_2019_05_RAI...
# Done.
# Importing WC_Centers_ODAnalysis_2019_05_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2019_06_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2019_06_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2019_06_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2019_06_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2019_07_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2019_07_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2019_07_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2019_07_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2019_08_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2019_08_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2019_08_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2019_08_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2019_09_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2019_09_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2019_09_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2019_09_BUS...
# Done.
# Importing WC_Centers_ODAnalysis_2019_09_RAI...
# Done.
# Importing WC_Centers_ODAnalysis_2019_09_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2019_10_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2019_10_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2019_10_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2019_10_BUS...
# Done.
# Importing WC_Centers_ODAnalysis_2019_10_RAI...
# Done.
# Importing WC_Centers_ODAnalysis_2019_10_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2019_11_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2019_11_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2019_11_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2019_11_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2019_12_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2019_12_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2019_12_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2019_12_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2019_BM_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2019_BM_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2019_BM_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2019_BM_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2019_YR_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2019_YR_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2019_YR_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2019_YR_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2020_01_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2020_01_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2020_01_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2020_01_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2020_02_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2020_02_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2020_02_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2020_02_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2020_03_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2020_03_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2020_03_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2020_03_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2020_04_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2020_04_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2020_04_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2020_04_BUS...
# Done.
# Importing WC_Centers_ODAnalysis_2020_04_RAI...
# Done.
# Importing WC_Centers_ODAnalysis_2020_04_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2020_05_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2020_05_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2020_05_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2020_05_BUS...
# Done.
# Importing WC_Centers_ODAnalysis_2020_05_RAI...
# Done.
# Importing WC_Centers_ODAnalysis_2020_05_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2020_06_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2020_06_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2020_06_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2020_06_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2020_07_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2020_07_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2020_07_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2020_07_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2020_08_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2020_08_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2020_08_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2020_08_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2020_09_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2020_09_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2020_09_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2020_09_BUS...
# Done.
# Importing WC_Centers_ODAnalysis_2020_09_RAI...
# Done.
# Importing WC_Centers_ODAnalysis_2020_09_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2020_10_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2020_10_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2020_10_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2020_10_BUS...
# Done.
# Importing WC_Centers_ODAnalysis_2020_10_RAI...
# Done.
# Importing WC_Centers_ODAnalysis_2020_10_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2020_11_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2020_11_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2020_11_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2020_11_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2020_12_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2020_12_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2020_12_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2020_12_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2020_BM_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2020_BM_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2020_BM_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2020_BM_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2020_YR_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2020_YR_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2020_YR_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2020_YR_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2021_01_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2021_01_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2021_01_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2021_01_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2021_02_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2021_02_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2021_02_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2021_02_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2021_03_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2021_03_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2021_03_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2021_03_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2021_04_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2021_04_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2021_04_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2021_04_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2021_05_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2021_05_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2021_05_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2021_05_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2021_06_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2021_06_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2021_06_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2021_06_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2021_07_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2021_07_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2021_07_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2021_07_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2021_08_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2021_08_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2021_08_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2021_08_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2021_09_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2021_09_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2021_09_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2021_09_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2021_10_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2021_10_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2021_10_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2021_10_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2021_11_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2021_11_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2021_11_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2021_11_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2021_12_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2021_12_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2021_12_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2021_12_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2021_BM_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2021_BM_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2021_BM_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2021_BM_ALL...
# Done.
# Importing WC_Centers_ODAnalysis_2021_YR_TRU...
# Done.
# Importing WC_Centers_ODAnalysis_2021_YR_BIC...
# Done.
# Importing WC_Centers_ODAnalysis_2021_YR_PED...
# Done.
# Importing WC_Centers_ODAnalysis_2021_YR_ALL...
# Done.

# %%
dfImport['day_type'] = dfImport['day_type'].str[0:1]
dfImport['day_part'] = dfImport['day_part'].str[0:1]
dfImport
# Out:
#         OID  DID day_type day_part  odvolume  odtime mode date_range
# 0       101  101        0        0     15720   770.0  TRU    2019_01
# 1       101  101        0        1       984   812.0  TRU    2019_01
# 2       101  101        0        2      3093   881.0  TRU    2019_01
# 3       101  101        0        3      7330   743.0  TRU    2019_01
# 4       101  101        0        4      3056   703.0  TRU    2019_01
# ...     ...  ...      ...      ...       ...     ...  ...        ...
# 254126   91   91        2        1       240   858.0  ALL    2021_YR
# 254127   91   91        2        2      1946   862.0  ALL    2021_YR
# 254128   91   91        2        3      6621   851.0  ALL    2021_YR
# 254129   91   91        2        4      3892   902.0  ALL    2021_YR
# 254130   91   91        2        5      2418   890.0  ALL    2021_YR
#
# [12924535 rows x 8 columns]

# %%
dfImport.to_csv(os.path.join('intermediate','centers_small_districts_od_by_mode.csv'),index=False)

# %%
#!/bin/bash

curl -i -d '{"message": "hello world"}' \
    -H "content-type: application/json" \
    https://insight.streetlightdata.com/api/v2/debug/echo?key=SS5OKOrGT4rQw/FCXZs55eEPZd6u0nd1
Run ./debug-echo.sh from the command line to verify that you can connect to StreetLight's server and successfully authenticate using your API key. If you receive a HTTP 200 OK response, this test was successful.

$ ./echo.sh
HTTP/1.1 200 OK
Date: Sat, 01 Apr 2017 23:42:28 GMT
Content-Type: application/json
Content-Length: 55
Connection: keep-alive
Set-Cookie: __cfduid=de8ff844541eaa29a65ea6870b508baa71491090148; expires=Sun, 01-Apr-18 23:42:28 GMT; path=/; domain=.streetlightdata.com; HttpOnly
Signature: 08a12cbd0e03edec92da03abb8ad3d0a17507b63
Cache-Control: no-cache, no-store, must-revalidate
Pragma: no-cache
Expires: 0
Server: cloudflare-nginx
CF-RAY: 348f67b478f951ca-SJC

{
  "message": "hello world",
  "status": "success"
}
